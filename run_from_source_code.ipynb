# %% [markdown]
# ### I will be using this jupyter notebook to run my local changes on the source code

# %%
# Load raw CSV -> Convert them to pickle form with {"question_to_label":[], "answer_to_label": []}
# Save pickle form in format of <domain>_orignal.pkl where an example of <domain> is comcare/babybonus

# %%
"""
Obtain the lists of questions and answers from any format, particularly from the pickle file
"""
import pickle

def save_dict(obj, path):
    # Save in .pickle format
    with open(path, 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_dict(path):
    # Load .pickle format as dictionary
    with open(path, 'rb') as f:
        return pickle.load(f)

def extractQA(orignalDct):
    # Return list of questions and answers in list format
    # originalDct format: {"question_to_label": {<question 1>: <label that maps to answer>,...}, 
    #                      "answer_to_label": {<answer question 1>: <label for questions to be mapped to>}}
    # Handles 1-1 mapping of question-answer OR many-1 mapping of question-answer
    q2L = orignalDct["question_to_label"]
    a2L = orignalDct["answer_to_label"]
    

    l2A = dict()
    for a,l in a2L.items():
        l2A[l] = a


    questions = []
    answers = []

    for q,l in q2L.items():
        questions.append(q)
        answers.append(l2A[l])
    return questions , answers

def visualize_question_answer(questions, answers, show_pairs = 5):
    count = 1
    for question, answer in zip(questions, answers):
        print(f"Question {count}: {question}\n\n'{answer}''")
        print("="*117)
        count += 1
        if count > show_pairs:
            break

# %%
"""
Convert parallel lists of questions and answers to CSVs for dialogflow or Bani
"""
import csv

def convert_pickle_to_csv(questions, answers, file_name = "new.csv", is_bani = True):
    # Take in lists of question and answer where question-answer pair have the same index in both lists
    # Read each question-answer pair into csv
    with open(file_name, mode='w') as new_csv:
        csv_writer = csv.writer(new_csv, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

        count = 0
        for question, answer in zip(questions, answers):
            if is_bani:
                csv.writer.writerow([count, question, answer])
                count += 1
            else:
                # Format for dialogflow
                csv_writer.writerow([question, answer])

# %%
from Bani.Bani import Bani
from Bani.core.FAQ import FAQ
from Bani.core.defaults import defaultGenerateManager

def get_faq(dict_path, name, generator):
    """
    @param dict_path: str -> relative path to .pkl file with keys "question_to_label" and "answer_to_label"
    @param name: str -> Name of FAQ
    @param generator: GenerateManager -> Generator pipeline for augmenting questions. Set to none if not augmenting
    @output FAQ object
    """
    original_dict = load_dict(dict_path)
    questions, answers = extractQA(original_dict)
    
    resultFAQ = FAQ(name = name, questions = questions, answers = answers)
    if generator:
        resultFAQ.buildFAQ(generator = generator)
    else:
        resultFAQ.buildFAQ(generator = None)
    return resultFAQ

babyBonusFAQ = get_faq(dict_path = "./tutorialFAQs/baby_bonus_orignal.pkl", name = "babyBonus", generator = None)
comcareFAQ = get_faq(dict_path = "./tutorialFAQs/comcare_orignal.pkl", name = "comcare", generator = None)

"""
@param modelPath = None -> Download a pretrained model of the SentenceTransformers
@param assignVectors = True -> Assign vectors accordingly. 
@param FAQs: List of FAQ object
"""
bot = Bani(modelPath = None , FAQs =[babyBonusFAQ, comcareFAQ], assignVectors = True)

# bot.train("./checkpoints/dummy", lossName = "softmaxLayerLos1s", batchSize = 8, warmst)

# TODO: Convert FAQ object back to CSV

# Optional: Save FAQ
# babyBonusFAQ.save("./jamesFAQs/no_generate")
# comcareFAQ.save("./jamesFAQs/no_generate")

# Optional: Load FAQ
# babyBonusFAQ = FAQ("babyBonus")
# babyBonusFAQ.load("./jamesFAQs/no_generate")

# comcareFAQ = FAQ("comcare")
# comcareFAQ.load("./faqStore/no_generate")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c001b608dae0> in <module>
#      20     return resultFAQ
#      21
# ---> 22 babyBonusFAQ = get_faq(dict_path = "./tutorialFAQs/baby_bonus_orignal.pkl", name = "babyBonus", generator = None)
#      23 comcareFAQ = get_faq(dict_path = "./tutorialFAQs/comcare_orignal.pkl", name = "comcare", generator = None)
#      24
#
# <ipython-input-1-c001b608dae0> in get_faq(dict_path, name, generator)
#      10     @output FAQ object
#      11     """
# ---> 12     original_dict = load_dict(dict_path)
#      13     questions, answers = extractQA(original_dict)
#      14
#
# NameError: name 'load_dict' is not defined

# %%
# name must correspond to the .pkl file name. i.e. name = babyBonus, .pkl file = babyBonus.pkl
testFAQ = FAQ(name = "babyBonus")
testFAQ.load("./jamesFAQs/no_generate")

name = testFAQ.name
questions = testFAQ.questions
answers = testFAQ.answers
l2Q = testFAQ.l2Q
l2A = testFAQ.l2A
FAQ_units = testFAQ.FAQ

# %%
FAQ_units[0].orignal.__str__()
# Out:
# 'how can my organisation apply to be a baby bonus approved institution? 0'

# %% [markdown]
# ## Manual Inspection of Augmented Questions for their Semantic Integrity/Accuracy
#
# TODO:
# 1. Find out how to inspect nlpAug's results

# %%
"""
Inspecting defaultGenerateManager's generators and their corresponding producer

From the output, you will notice:
1. Different producers have their own properties and methods
2. nlpAug generator's producer have no "name" property
"""
from Bani.core.defaults import defaultGenerateManager

for i in range(len(defaultGenerateManager.generators)):
    generator = defaultGenerateManager.generators[i]
    producer = generator.producer
    print(f"Generator Name: {generator.name}")
    print(f"Picking {generator.num} questions")
    if "name" in dir(producer):
        print(f"Producer Name: {producer.name}")
    else:
        print("*No known producer name*")
    print(f"Producer's dir:\n {dir(producer)[27:]}")
    print("="*115 + "\n")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Generator Name: SymSub
# Picking 3 questions
# Producer Name: Sense-disambiguated Synonym Substitution
# Producer's dir:
#  ['_get_synonyms', 'batch_generate', 'discount_factor', 'encoder', 'generate', 'name', 'threshold']
# ===================================================================================================================
#
# Generator Name: FPM
# Picking 3 questions
# Producer Name: Fuzzy Question Pattern Matching
# Producer's dir:
#  ['_format_output', '_generate_patterns', '_has_multiple_question', '_preprocess', '_split_question', 'batch_generate', 'generate', 'matcher', 'name', 'patterns']
# ===================================================================================================================
#
# Generator Name: EDA
# Picking 3 questions
# Producer Name: Easy Data Augmentation Techniques
# Producer's dir:
#  ['_get_only_chars', '_get_synonyms', '_random_deletion', '_random_insertion', '_random_swap', '_swap_word', '_synonym_replacement', 'alpha_ri', 'alpha_rs', 'alpha_sr', 'batch_generate', 'generate', 'name', 'num_aug', 'p_rd']
# ===================================================================================================================
#
# Generator Name: nlpAug
# Picking 2 questions
# *No known producer name*
# Producer's dir:
#  ['augs', 'exact_batch_generate']
# ===================================================================================================================

# %%
"""
Pass in original questions, and generate their corresponding augmented questions for inspection in subsequent cells
You may pass in only selected number of original questions e.g. questions[:3] to choose 3 questions
"""
CHOOSE_COUNT = 10
from Bani.core.defaults import defaultGenerateManager
from collections import defaultdict

original_dict = load_dict("./tutorialFAQs/baby_bonus_orignal.pkl")
questions, answers = extractQA(original_dict)

symsub_producer = defaultGenerateManager.generators[0].producer
fpm_producer = defaultGenerateManager.generators[1].producer
eda_producer = defaultGenerateManager.generators[2].producer
nlpAug_producer = defaultGenerateManager.generators[3].producer

result_symsub = defaultdict(list)
result_fpm = defaultdict(list)
result_eda = defaultdict(list)
result_nlpAug = defaultdict(list)
for question in questions[:CHOOSE_COUNT]:
    result_symsub[question] = symsub_producer.generate(question)
    result_fpm[question] = fpm_producer.generate(question)
    result_eda[question] = eda_producer.generate(question)    
    result_nlpAug[question] = nlpAug_producer.exact_batch_generate(question,3)
# Out:
# 100%|██████████| 70/70 [00:06<00:00, 11.44it/s]
# 100%|██████████| 215/215 [00:16<00:00, 12.92it/s]
# 100%|██████████| 191/191 [00:15<00:00, 12.67it/s]
# 100%|██████████| 67/67 [00:05<00:00, 12.40it/s]
# 100%|██████████| 139/139 [00:11<00:00, 11.80it/s]
# 100%|██████████| 61/61 [00:05<00:00, 11.81it/s]
# 100%|██████████| 74/74 [00:06<00:00, 12.22it/s]
# 100%|██████████| 78/78 [00:05<00:00, 13.47it/s]
# 100%|██████████| 68/68 [00:05<00:00, 12.21it/s]
# 100%|██████████| 97/97 [00:07<00:00, 12.67it/s]

# %%
# Questions that we have
for num in range(len(questions)):
    question = questions[num]
    print(f"Q{num + 1}: \n{question}")
    print("-"*115 + "\n")
# Out:
# Q1:
# How can my organisation apply to be a Baby Bonus Approved Institution?
# -------------------------------------------------------------------------------------------------------------------
#
# Q2:
# I have entered the Unique Entity Number (UEN) using 'Join as an Approved Institution (AI)' service, but your system does not have matching records of my Unique Entity Number (UEN). Can I still submit my application?
# -------------------------------------------------------------------------------------------------------------------
#
# Q3:
# I have entered the Unique Entity Number (UEN) using the 'Join as Approved Institution (AI)' service, but your system indicated that my Unique Entity Number (UEN) is invalid, what should I do?
# -------------------------------------------------------------------------------------------------------------------
#
# Q4:
# Is there a validity period to be a Baby Bonus Approved Institution?
# -------------------------------------------------------------------------------------------------------------------
#
# Q5:
# How much does an organisation need to pay to register as an Approved Institution (AI) with Ministry of Social and Family Development (MSF)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q6:
# Why is my Approved Institution (AI) application not approved?
# -------------------------------------------------------------------------------------------------------------------
#
# Q7:
# Who do I contact for enquiries and feedback on Approved Institutions (AI)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q8:
# Where can I find the list of optical shops, which allow the use the CDA funds?
# -------------------------------------------------------------------------------------------------------------------
#
# Q9:
# How do I find out more information about Approved Institutions (AI)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q10:
# If an AI makes a refund into the CDA, how long will the process take before I receive the refund?
# -------------------------------------------------------------------------------------------------------------------
#
# Q11:
# My centre is an Approved Institution. Can I request for an additional or higher-resolution Baby Bonus Approved Institution sticker?
# -------------------------------------------------------------------------------------------------------------------
#
# Q12:
# What is a Baby Bonus Approved Institution?
# -------------------------------------------------------------------------------------------------------------------
#
# Q13:
# Who can apply to be a Baby Bonus Approved Institution?
# -------------------------------------------------------------------------------------------------------------------
#
# Q14:
# How can I check whether my organisation is eligible to be a Baby Bonus Approved Institution?
# -------------------------------------------------------------------------------------------------------------------
#
# Q15:
# Are eligible institutions required to register all of its business entities/centres belonging to the same Company as a Baby Bonus AI?
# -------------------------------------------------------------------------------------------------------------------
#
# Q16:
# What is CorpPass?
# -------------------------------------------------------------------------------------------------------------------
#
# Q17:
# I am an Approved Person (AP) but do not have a CorpPass account. Can I still login to Approved Institution (AI) Portal using Singpass to access the e-services?
# -------------------------------------------------------------------------------------------------------------------
#
# Q18:
# My entity has already registered for CorpPass. However I am still not able to login to Approved Institution (AI) Portal to access AI e-services.
# -------------------------------------------------------------------------------------------------------------------
#
# Q19:
# Can I still transact using my SingPass after signing up for CorpPass?
# -------------------------------------------------------------------------------------------------------------------
#
# Q20:
# Why must we transit to CorpPass?
# -------------------------------------------------------------------------------------------------------------------
#
# Q21:
# Is my entity eligible for CorpPass?
# -------------------------------------------------------------------------------------------------------------------
#
# Q22:
# Is it true that as long as I have a CorpPass, I can apply to be an Approved Institution or Approved Person?
# -------------------------------------------------------------------------------------------------------------------
#
# Q23:
# I am a CorpPass user and I have registered my entity as an Approved Institution (AI) on behalf of my Approved Person (AP). How can I complete the AI acceptance?
# -------------------------------------------------------------------------------------------------------------------
#
# Q24:
# I am an Approved Person (AP) and have submitted a request for a change of AP. How can the new AP accept the terms and conditions?
# -------------------------------------------------------------------------------------------------------------------
#
# Q25:
# How can I update MSF of the details of my business and the Approved Persons(AP) particulars?
# -------------------------------------------------------------------------------------------------------------------
#
# Q26:
# Can my organisation withdraw from the Approved Institution (AI) status?
# -------------------------------------------------------------------------------------------------------------------
#
# Q27:
# If an Approved Institution (AI) needs to update its bank account details, does it need to inform Ministry of Social and Family Development (MSF)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q28:
# How can I change the Approved Person for my Approved Institution?
# -------------------------------------------------------------------------------------------------------------------
#
# Q29:
# What Child Development Account (CDA) deduction records do Approved Institutions (AI) need to maintain?
# -------------------------------------------------------------------------------------------------------------------
#
# Q30:
# How do I ensure proper deductions from the Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q31:
# How can I check the identity of the Child Development Account (CDA) member and the siblings?
# -------------------------------------------------------------------------------------------------------------------
#
# Q32:
# When do I need to check the relationship between the Child Development Account (CDA) member and his/her siblings?
# -------------------------------------------------------------------------------------------------------------------
#
# Q33:
# What is the penalty for misuse of the Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q34:
# When do Approved Institutions need to make a refund to the Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q35:
# I tried to make a refund using 'Refund to the Child Development Account (CDA) service'. It indicates that "the selected institution is not allowed to perform the refund request".
# -------------------------------------------------------------------------------------------------------------------
#
# Q36:
# Can the Approved Institution (AI) make a refund in the Child Development Account (CDA) on behalf of parents for the payments made in cash?
# -------------------------------------------------------------------------------------------------------------------
#
# Q37:
# I am an Approved Institution. I have submitted a refund request using the AI portal. How long will it take for the refund to be credited into the child’s CDA?
# -------------------------------------------------------------------------------------------------------------------
#
# Q38:
# I am an Approved Institution. I have submitted a refund request using AI portal How can I check if the refund has been credited into the child’s CDA?
# -------------------------------------------------------------------------------------------------------------------
#
# Q39:
# I am supposed to receive a refund from the Approved Institution. How do I know whether the refund has been credited into my child’s CDA?
# -------------------------------------------------------------------------------------------------------------------
#
# Q40:
# Can Approved Institutions (AIs) deduct administrative fees from the Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q41:
# How do I join the Baby Bonus Scheme?
# -------------------------------------------------------------------------------------------------------------------
#
# Q42:
# What are the Baby Bonus Benefits for my child?
# -------------------------------------------------------------------------------------------------------------------
#
# Q43:
# If my spouse and I were not citizens at the time of my child’s birth, what are the pro-rated benefits that my child will receive?
# -------------------------------------------------------------------------------------------------------------------
#
# Q44:
# What are the Baby Bonus benefits for children of unwed parents?
# -------------------------------------------------------------------------------------------------------------------
#
# Q45:
# Are children of unwed parents eligible to join the Baby Bonus Scheme?
# -------------------------------------------------------------------------------------------------------------------
#
# Q46:
# I am not married. Will my child be eligible for the Cash Gift?
# -------------------------------------------------------------------------------------------------------------------
#
# Q47:
# What other benefits can unwed parents qualify for?
# -------------------------------------------------------------------------------------------------------------------
#
# Q48:
# Will I still receive full Baby Bonus benefits if I abandon or give my child up for adoption?
# -------------------------------------------------------------------------------------------------------------------
#
# Q49:
# When will I receive the cash gift and CDA contributions?
# -------------------------------------------------------------------------------------------------------------------
#
# Q50:
# What is Medisave Grant for Newborns?
# -------------------------------------------------------------------------------------------------------------------
#
# Q51:
# Do I need to pay back the Baby Bonus benefits if my child gives up his/her citizenship after 21 years old?
# -------------------------------------------------------------------------------------------------------------------
#
# Q52:
# Will Baby Bonus benefits be recovered when the child’s parents divorce?
# -------------------------------------------------------------------------------------------------------------------
#
# Q53:
# What is Baby Bonus Online (BBO)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q54:
# When can my child join the Baby Bonus scheme?
# -------------------------------------------------------------------------------------------------------------------
#
# Q55:
# How do I submit my Baby Bonus supporting documents?
# -------------------------------------------------------------------------------------------------------------------
#
# Q56:
# My child was born overseas in 2015 and she just attained Singapore Citizenship. Can I still receive the SG50 Jubilee gift?
# -------------------------------------------------------------------------------------------------------------------
#
# Q57:
# When was Baby Bonus Scheme implemented?
# -------------------------------------------------------------------------------------------------------------------
#
# Q58:
# Can I open a CDA for my child who is 12 and above?
# -------------------------------------------------------------------------------------------------------------------
#
# Q59:
# What is the Child Development Co-Savings Scheme?
# -------------------------------------------------------------------------------------------------------------------
#
# Q60:
# What is Baby Bonus scheme?
# -------------------------------------------------------------------------------------------------------------------
#
# Q61:
# How do I update my child’s new name?
# -------------------------------------------------------------------------------------------------------------------
#
# Q62:
# What is Baby Bonus hotline number?
# -------------------------------------------------------------------------------------------------------------------
#
# Q63:
# I have lost my child’s Baby Bonus card. How do I apply for a replacement Baby Bonus card?
# -------------------------------------------------------------------------------------------------------------------
#
# Q64:
# How is the birth order determined? Are non-Singaporean children/step children and children given up for adoption counted in the birth order?
# -------------------------------------------------------------------------------------------------------------------
#
# Q65:
# I have another child from my second marriage. Why is the child from my second marriage considered as the first child?
# -------------------------------------------------------------------------------------------------------------------
#
# Q66:
# How are twins and triplets counted in birth order?
# -------------------------------------------------------------------------------------------------------------------
#
# Q67:
# What happens to the counting of birth order when a child passes away?
# -------------------------------------------------------------------------------------------------------------------
#
# Q68:
# What happens to the counting of birth order when there is a stillbirth?
# -------------------------------------------------------------------------------------------------------------------
#
# Q69:
# There is a change in my children's birth order. Do I need to inform MSF?
# -------------------------------------------------------------------------------------------------------------------
#
# Q70:
# Is my child eligible for the Baby Bonus Scheme?
# -------------------------------------------------------------------------------------------------------------------
#
# Q71:
# Is my adopted child eligible for the Baby Bonus Scheme?
# -------------------------------------------------------------------------------------------------------------------
#
# Q72:
# If I am married to the child's father after the birth of my child, will my child be eligible for the Baby Bonus scheme?
# -------------------------------------------------------------------------------------------------------------------
#
# Q73:
# Why are single parents not eligible for the enhanced Baby Bonus scheme?
# -------------------------------------------------------------------------------------------------------------------
#
# Q74:
# If my child has passed away, what will happen to the Baby Bonus benefits?
# -------------------------------------------------------------------------------------------------------------------
#
# Q75:
# What will be the Baby Bonus entitlement for my child, who has just obtained Singapore Citizenship?
# -------------------------------------------------------------------------------------------------------------------
#
# Q76:
# I am currently not married but will be getting married to my child’s father soon. Can my child’s Baby Bonus benefits be reviewed?
# -------------------------------------------------------------------------------------------------------------------
#
# Q77:
# Who will be eligible for Government matching contribution?
# -------------------------------------------------------------------------------------------------------------------
#
# Q78:
# I am married but not to my child’s father. Would my child be eligible for Baby Bonus?
# -------------------------------------------------------------------------------------------------------------------
#
# Q79:
# If my spouse and I are Singapore Permanent residents and my child is born in Singapore. Does my child qualify for Baby Bonus?
# -------------------------------------------------------------------------------------------------------------------
#
# Q80:
# My spouse and I are Singaporeans. My baby was born overseas, would he be eligible for Baby Bonus?
# -------------------------------------------------------------------------------------------------------------------
#
# Q81:
# I recently married my child’s natural father. What should I do for my child to be eligible for baby Bonus Scheme?
# -------------------------------------------------------------------------------------------------------------------
#
# Q82:
# What is the minimum hardware requirement for Baby Bonus Online (BBO)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q83:
# What is the minimum software requirement for Baby Bonus Online (BBO)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q84:
# How do I check the version of my browser?
# -------------------------------------------------------------------------------------------------------------------
#
# Q85:
# Why am I encountering the error message, "You have already logged in. Simultaneous sessions are not allowed"?
# -------------------------------------------------------------------------------------------------------------------
#
# Q86:
# I am experiencing slow response when accessing the Baby Bonus Online (BBO) application. What is wrong?
# -------------------------------------------------------------------------------------------------------------------
#
# Q87:
# Can I click the browser's back button to go back to the previous page when accessing Baby Bonus Online (BBO)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q88:
# Why is my access to baby bonus online denied after Singpass login is successful?
# -------------------------------------------------------------------------------------------------------------------
#
# Q89:
# What I need to do if I hit a page error or I am unable to login for Baby Bonus Online (BBO)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q90:
# How do I print a page within Baby Bonus Online (BBO)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q91:
# My latest details in MyInfo was not displayed when I try complete the Baby Bonus online form. What should I do?
# -------------------------------------------------------------------------------------------------------------------
#
# Q92:
# I encountered an error when I tried to log in to Baby Bonus Online. What should I do?
# -------------------------------------------------------------------------------------------------------------------
#
# Q93:
# I have submitted request to open CDA. Why is my status still at In-progress?
# -------------------------------------------------------------------------------------------------------------------
#
# Q94:
# My spouse is a foreigner. How should I complete his/her details in the application form?
# -------------------------------------------------------------------------------------------------------------------
#
# Q95:
# I am residing overseas. I cannot enter my overseas contact number in the application form. Please help.
# -------------------------------------------------------------------------------------------------------------------
#
# Q96:
# My application status is Action Required by Applicant. What should I do?
# -------------------------------------------------------------------------------------------------------------------
#
# Q97:
# What can I use the Baby Bonus cash gift for?
# -------------------------------------------------------------------------------------------------------------------
#
# Q98:
# When will I receive the Baby Bonus cash gifts?
# -------------------------------------------------------------------------------------------------------------------
#
# Q99:
# Will cash gift be credited to the CDA directly?
# -------------------------------------------------------------------------------------------------------------------
#
# Q100:
# Can I enter my own bank account to receive the cash gift and CDA matching?
# -------------------------------------------------------------------------------------------------------------------
#
# Q101:
# When will I receive the next cash gift?
# -------------------------------------------------------------------------------------------------------------------
#
# Q102:
# How do I enter my OCBC bank account number to receive the Cash Gift?
# -------------------------------------------------------------------------------------------------------------------
#
# Q103:
# Will I be taxed for the Baby Bonus cash gift received?
# -------------------------------------------------------------------------------------------------------------------
#
# Q104:
# Will my child be eligible for the Child Development Account (CDA) First Step announced during Budget Day?
# -------------------------------------------------------------------------------------------------------------------
#
# Q105:
# I have not saved in the Child Development Account (CDA) yet. What is the $600 which was credited to the CDA?
# -------------------------------------------------------------------------------------------------------------------
#
# Q106:
# When will I receive the Child Development Account (CDA) First Step?
# -------------------------------------------------------------------------------------------------------------------
#
# Q107:
# How long does it take to open the CDA with the new bank? Is the transfer of funds from Standard Chartered Bank (Singapore) to the new bank immediate? How long does the process take?
# -------------------------------------------------------------------------------------------------------------------
#
# Q108:
# I have not received the letter from MSF on the transfer notice. Can I proceed to change to a new Child Development Account (CDA) bank?
# -------------------------------------------------------------------------------------------------------------------
#
# Q109:
# What will happen if I do not change the Standard Chartered Bank (SCB) Child Development Account (CDA) to another CDA bank?
# -------------------------------------------------------------------------------------------------------------------
#
# Q110:
# I have never used the Baby Bonus Online Portal as I do not have a SingPass. Is there another way for me to change the Child Development Account (CDA) to a different bank?
# -------------------------------------------------------------------------------------------------------------------
#
# Q111:
# My child’s Child Development Account (CDA) is with Standard Chartered Bank (Singapore) and my child will be 12 years old in 2018. Is there a need for me to change to another bank?
# -------------------------------------------------------------------------------------------------------------------
#
# Q112:
# Why was Standard Chartered Bank (Singapore) not re-appointed as a Child Development Account (CDA) bank?
# -------------------------------------------------------------------------------------------------------------------
#
# Q113:
# How do Approved institutions collect fees from the Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q114:
# My organisation is a NETS merchant. Will there be additional fees to provide the Baby Bonus NETS service?
# -------------------------------------------------------------------------------------------------------------------
#
# Q115:
# How do I apply to provide the Baby Bonus NETS service?
# -------------------------------------------------------------------------------------------------------------------
#
# Q116:
# How does the Baby Bonus NETS card look like?
# -------------------------------------------------------------------------------------------------------------------
#
# Q117:
# What is the GIRO process of collecting fees from a Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q118:
# Can the Child Development Account (CDA) be used for other siblings of the child?
# -------------------------------------------------------------------------------------------------------------------
#
# Q119:
# Can the Child Development Account (CDA) be used for any persons, other than the child and/or the siblings?
# -------------------------------------------------------------------------------------------------------------------
#
# Q120:
# Is there an age limit for the child's siblings to use the Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q121:
# Why is my child’s cash gift and/ or matching contribution pro-rated instead of the full amount?
# -------------------------------------------------------------------------------------------------------------------
#
# Q122:
# Can the Baby Bonus Cash gift be disbursed earlier?
# -------------------------------------------------------------------------------------------------------------------
#
# Q123:
# What is the difference between the old CDA scheme and the CDA First Step for children born from 24 Mar 2016?
# -------------------------------------------------------------------------------------------------------------------
#
# Q124:
# What is the address for Baby Bonus office?
# -------------------------------------------------------------------------------------------------------------------
#
# Q125:
# Who has the right to receive the baby bonus?
# -------------------------------------------------------------------------------------------------------------------
#
# Q126:
# What documents do I need to join the Baby Bonus Scheme?
# -------------------------------------------------------------------------------------------------------------------
#
# Q127:
# Is it compulsory to do a pre-birth registration for the Baby Bonus Scheme?
# -------------------------------------------------------------------------------------------------------------------
#
# Q128:
# Can I do a pre-birth registration for the Baby Bonus Scheme before my child is born?
# -------------------------------------------------------------------------------------------------------------------
#
# Q129:
# Can I do a pre-birth registration for the Baby Bonus Scheme if my child is adopted?
# -------------------------------------------------------------------------------------------------------------------
#
# Q130:
# Can I continue with the pre-birth registration for Baby Bonus Scheme if I do not know the Estimated Date of Delivery (EDD)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q131:
# Can my child still join the Baby Bonus Scheme by submitting a hardcopy form?
# -------------------------------------------------------------------------------------------------------------------
#
# Q132:
# If I have made pre-birth registration and selected the Cash Gift bank account holder and Child Development Account (CDA) trustee, can these be changed?
# -------------------------------------------------------------------------------------------------------------------
#
# Q133:
# I need some help to join the Baby Bonus Scheme online. Who can I approach?
# -------------------------------------------------------------------------------------------------------------------
#
# Q134:
# What happens after I have submitted the online form for Baby Bonus Scheme?
# -------------------------------------------------------------------------------------------------------------------
#
# Q135:
# Where can I check my Baby Bonus application status?
# -------------------------------------------------------------------------------------------------------------------
#
# Q136:
# I just found out that my child has joined the scheme without my agreement. Can you change the bank account holder or Child Development Account (CDA) trustee to me?
# -------------------------------------------------------------------------------------------------------------------
#
# Q137:
# I have submitted an application for Baby Bonus Scheme. How can I open the CDA for my child?
# -------------------------------------------------------------------------------------------------------------------
#
# Q138:
# I have submitted a pre-birth registration. How can I provide my newborns details?
# -------------------------------------------------------------------------------------------------------------------
#
# Q139:
# What is One-Stop Service Centre?
# -------------------------------------------------------------------------------------------------------------------
#
# Q140:
# How can I check the CDA notification which was sent to me via the bank website?
# -------------------------------------------------------------------------------------------------------------------
#
# Q141:
# Why is my Baby Bonus application unsuccessful?
# -------------------------------------------------------------------------------------------------------------------
#
# Q142:
# Can I cancel my child’s Baby Bonus application?
# -------------------------------------------------------------------------------------------------------------------
#
# Q143:
# I have submitted a Pre-birth registration. Why the status is still at submitted?
# -------------------------------------------------------------------------------------------------------------------
#
# Q144:
# I have applied for the Baby Bonus Scheme. How can I open a Child Development Account (CDA) for my child?
# -------------------------------------------------------------------------------------------------------------------
#
# Q145:
# Is there a limit to the number of Child Development Accounts per family?
# -------------------------------------------------------------------------------------------------------------------
#
# Q146:
# What is the Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q147:
# Why do you still need the foreigner and 3rd party Child Development Account (CDA) trustee to make a trip to the bank, when most transactions can already be done online?
# -------------------------------------------------------------------------------------------------------------------
#
# Q148:
# Can you send the Child Development Account (CDA) authorisation letter to another address other than my official one?
# -------------------------------------------------------------------------------------------------------------------
#
# Q149:
# Is it necessary to make a deposit to open a Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q150:
# Why do you have an age limit for Child Development Account (CDA) trustee but not the bank account holder to receive Cash Gift?
# -------------------------------------------------------------------------------------------------------------------
#
# Q151:
# I have already selected my spouse as a Child Development Account (CDA) trustee when I join scheme. Why is the Child Development Account (CDA) not opened yet?
# -------------------------------------------------------------------------------------------------------------------
#
# Q152:
# I have the custody, care and control; or care and control of my child. How can I change the cash gift and/or Child Development Account (CDA) trustee to me?
# -------------------------------------------------------------------------------------------------------------------
#
# Q153:
# Can I open a new Child Development Account (CDA) directly with any of the Child Development Account (CDA) banks?
# -------------------------------------------------------------------------------------------------------------------
#
# Q154:
# Will there be any penalties or charges for a change in Child Development Account (CDA) bank?
# -------------------------------------------------------------------------------------------------------------------
#
# Q155:
# If I change the Child Development Account (CDA) bank, will I forfeit/ have to return the benefits given by the bank (e.g. bonus interest rate)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q156:
# How will I know which Child Development Account (CDA) bank suits me better?
# -------------------------------------------------------------------------------------------------------------------
#
# Q157:
# I have changed my name/child's name. Do I need to inform the Ministry of Social and Family Development (MSF) and my Child Development Account (CDA) bank?
# -------------------------------------------------------------------------------------------------------------------
#
# Q158:
# When will the Child Development Account (CDA) be closed?
# -------------------------------------------------------------------------------------------------------------------
#
# Q159:
# What are the Child Development Account (CDA) Bank contact numbers?
# -------------------------------------------------------------------------------------------------------------------
#
# Q160:
# How can I open a Child Development Account (CDA)? I am the Child Development Account (CDA) trustee.
# -------------------------------------------------------------------------------------------------------------------
#
# Q161:
# How can I open a Child Development Account (CDA)? My spouse is the Child Development Account (CDA) trustee.
# -------------------------------------------------------------------------------------------------------------------
#
# Q162:
# How to open a Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q163:
# Can I close my Child Development Account (CDA) and withdraw the money?
# -------------------------------------------------------------------------------------------------------------------
#
# Q164:
# How do I activate the Child Development Account (CDA) card?
# -------------------------------------------------------------------------------------------------------------------
#
# Q165:
# Can I transfer my child’s Child Development Account (CDA) balance to another child’s CDA?
# -------------------------------------------------------------------------------------------------------------------
#
# Q166:
# How can I withdraw the money which I have wrongly deposited in the CDA?
# -------------------------------------------------------------------------------------------------------------------
#
# Q167:
# What is the deadline for me to open the CDA for my child?
# -------------------------------------------------------------------------------------------------------------------
#
# Q168:
# Do I need to open a current account with the bank in order to open the CDA?
# -------------------------------------------------------------------------------------------------------------------
#
# Q169:
# POSB has opened 2 account numbers. Which bank account should I deposit money into to receive the government matching?
# -------------------------------------------------------------------------------------------------------------------
#
# Q170:
# Must I open a CDA when I enrol my child?
# -------------------------------------------------------------------------------------------------------------------
#
# Q171:
# Who can be the Child Development Account (CDA) Trustee?
# -------------------------------------------------------------------------------------------------------------------
#
# Q172:
# What is CDA trustee?
# -------------------------------------------------------------------------------------------------------------------
#
# Q173:
# How do I tag my child’s Child Development Account (CDA) to my internet banking profile?
# -------------------------------------------------------------------------------------------------------------------
#
# Q174:
# Which are the CDA banks and when did they start providing CDA services?
# -------------------------------------------------------------------------------------------------------------------
#
# Q175:
# When will CDA bank record be updated to show my savings deposited recently?
# -------------------------------------------------------------------------------------------------------------------
#
# Q176:
# I used to receive letters on the amount of Government matching received. Why am I not receiving the letter now?
# -------------------------------------------------------------------------------------------------------------------
#
# Q177:
# My husband/wife who is also the CDA Trustee has passed away. How can I change trustee to myself?
# -------------------------------------------------------------------------------------------------------------------
#
# Q178:
# Where can I find the GIRO form for CDA deduction?
# -------------------------------------------------------------------------------------------------------------------
#
# Q179:
# Can I withdraw the Child Development Account (CDA) funds to pay for my child's insurance rider?
# -------------------------------------------------------------------------------------------------------------------
#
# Q180:
# Can I be the CDA trustee if my spouse is not contactable?
# -------------------------------------------------------------------------------------------------------------------
#
# Q181:
# What is the difference between a CDA Trustee and Bank Account Holder?
# -------------------------------------------------------------------------------------------------------------------
#
# Q182:
# My child’s CDA will be closing this year. Can I still change my child’s CDA trustee?
# -------------------------------------------------------------------------------------------------------------------
#
# Q183:
# I have saved in excess of the CDA Government contributions cap. Will the excess also be transferred to PSEA?
# -------------------------------------------------------------------------------------------------------------------
#
# Q184:
# I have saved in excess of the CDA cap and the CDA trustee is a third party. Will the excess be credited to the third party trustee or parents bank account?
# -------------------------------------------------------------------------------------------------------------------
#
# Q185:
# What type of expenses can I use the PSEA funds for?
# -------------------------------------------------------------------------------------------------------------------
#
# Q186:
# How do I log in to Baby Bonus Online?
# -------------------------------------------------------------------------------------------------------------------
#
# Q187:
# Where can I get the Baby Bonus booklet?
# -------------------------------------------------------------------------------------------------------------------
#
# Q188:
# How can I view the payment details of the cash gifts?
# -------------------------------------------------------------------------------------------------------------------
#
# Q189:
# How can I change my bank account to receive cash gift(s)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q190:
# I have submitted my request to change bank account for receiving cash gift online. How do I know if my request is received and updated?
# -------------------------------------------------------------------------------------------------------------------
#
# Q191:
# How can I change the Child Development Account (CDA) trustee?
# -------------------------------------------------------------------------------------------------------------------
#
# Q192:
# When do I need to change the Child Development Account (CDA) trustee?
# -------------------------------------------------------------------------------------------------------------------
#
# Q193:
# I have recently submitted a request for change of Child Development Account (CDA) trustee online. How do I know the status of the change?
# -------------------------------------------------------------------------------------------------------------------
#
# Q194:
# How can I change my Child Development Account (CDA) bank?
# -------------------------------------------------------------------------------------------------------------------
#
# Q195:
# I have submitted a request to change Child Development Account (CDA) bank through Baby Bonus Online. Can I cancel my request?
# -------------------------------------------------------------------------------------------------------------------
#
# Q196:
# What will happen to my existing GIRO arrangement and ATM card after I submit my request to change Child Development Account (CDA) bank?
# -------------------------------------------------------------------------------------------------------------------
#
# Q197:
# Can my GIRO arrangements be transferred to the new CDA?
# -------------------------------------------------------------------------------------------------------------------
#
# Q198:
# I have recently submitted a request for change of Child Development Account (CDA) bank online. How do I know if the Child Development Account (CDA) bank has been changed?
# -------------------------------------------------------------------------------------------------------------------
#
# Q199:
# How much can I save in the Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q200:
# How can I view my Child Development Account (CDA) transactions?
# -------------------------------------------------------------------------------------------------------------------
#
# Q201:
# How can I transfer my Child Development Account (CDA) funds to Post-Secondary Education Account (PSEA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q202:
# What is the processing time for a change of Child Development Account (CDA) bank?
# -------------------------------------------------------------------------------------------------------------------
#
# Q203:
# Where can I download the Baby Bonus kit in Chinese, Malay and Tamil?
# -------------------------------------------------------------------------------------------------------------------
#
# Q204:
# How can I obtain a letter to change CDA bank?
# -------------------------------------------------------------------------------------------------------------------
#
# Q205:
# How do I view the benefits that my child has received?
# -------------------------------------------------------------------------------------------------------------------
#
# Q206:
# How can I update my contact details?
# -------------------------------------------------------------------------------------------------------------------
#
# Q207:
# How much is the remaining dollar-for-dollar Government matching in my child’s Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q208:
# What does the Baby Bonus Parenting Resources consist of?
# -------------------------------------------------------------------------------------------------------------------
#
# Q209:
# Why did the Government decide to put parenting information online?
# -------------------------------------------------------------------------------------------------------------------
#
# Q210:
# What makes the Baby Bonus Parenting Re-sources different from other parenting websites?
# -------------------------------------------------------------------------------------------------------------------
#
# Q211:
# What is the source of the parenting information?
# -------------------------------------------------------------------------------------------------------------------
#
# Q212:
# When can I receive the Government matching in the Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q213:
# How can I save in the Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q214:
# Do I need to verify my Child Development Account (CDA) transactions?
# -------------------------------------------------------------------------------------------------------------------
#
# Q215:
# Can I receive the Government matching in the Child Development Account (CDA), if the deposit is not made by me?
# -------------------------------------------------------------------------------------------------------------------
#
# Q216:
# When can I start saving in the Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q217:
# What does CDA dollar-for-dollar matching refer to?
# -------------------------------------------------------------------------------------------------------------------
#
# Q218:
# How do I receive the Baby Bonus letters from Ministry of Social and Family Development (MSF) if I am overseas?
# -------------------------------------------------------------------------------------------------------------------
#
# Q219:
# How do I update my new address with Ministry of Social and Family Development (MSF) if I have moved?
# -------------------------------------------------------------------------------------------------------------------
#
# Q220:
# How can I update Ministry of Social and Family Development (MSF) with my new Singapore Citizenship Identification number and SingPass to log into Baby Bonus Online (BBO)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q221:
# Where can I use the Child Development Account (CDA) funds?
# -------------------------------------------------------------------------------------------------------------------
#
# Q222:
# How can I make payment using my Child Development Account (CDA) funds?
# -------------------------------------------------------------------------------------------------------------------
#
# Q223:
# Can I use the Child Development Account (CDA) to pay for a child care centre/ kindergarten's deposit and registration fees?
# -------------------------------------------------------------------------------------------------------------------
#
# Q224:
# If I have made a deposit in cash to the Approved Institution (AI), can the Approved Institution (AI) refund to the Child Development Account (CDA) on my behalf?
# -------------------------------------------------------------------------------------------------------------------
#
# Q225:
# Can I use the Child Development Account (CDA) to pay for enrichment and optional programmes conducted in a child care centre or kindergarten?
# -------------------------------------------------------------------------------------------------------------------
#
# Q226:
# How can I identify an Approved Institution for the use of Child Development Account (CDA) funds?
# -------------------------------------------------------------------------------------------------------------------
#
# Q227:
# Can I withdraw money from the Child Development Account (CDA) using an ATM machine?
# -------------------------------------------------------------------------------------------------------------------
#
# Q228:
# Can I use the funds in the Child Development Account (CDA) for my child’s primary or secondary school fees?
# -------------------------------------------------------------------------------------------------------------------
#
# Q229:
# What document do I need to produce if I want to use my child’s CDA for his/her siblings?
# -------------------------------------------------------------------------------------------------------------------
#
# Q230:
# Can I withdraw funds from the Child Development Account (CDA) to pay for my child's insurance?
# -------------------------------------------------------------------------------------------------------------------
#
# Q231:
# What is the expiry date for CDA?
# -------------------------------------------------------------------------------------------------------------------
#
# Q232:
# Can I use the CDA First Step grant before I deposit any money?
# -------------------------------------------------------------------------------------------------------------------
#
# Q233:
# How do I check my Child Development Account (CDA) pin number?
# -------------------------------------------------------------------------------------------------------------------
#
# Q234:
# Why am I not allowed to use the Child Development Account (CDA) to pay for my child’s milk powder and diapers?
# -------------------------------------------------------------------------------------------------------------------
#
# Q235:
# Do I need to wait for the Child Development Account (CDA) matching contributions to be deposited before I can use the CDA funds?
# -------------------------------------------------------------------------------------------------------------------
#
# Q236:
# Can I use CHAS and Baby Bonus card together in one transaction?
# -------------------------------------------------------------------------------------------------------------------
#
# Q237:
# Can I use a joint account to apply for Child Development Account?
# -------------------------------------------------------------------------------------------------------------------
#
# Q238:
# I paid my child’s Medisave-approved private integrated plans in cash. How can I apply for reimbursement from the CDA?
# -------------------------------------------------------------------------------------------------------------------
#
# Q239:
# What are the types of approved education/healthcare expenses under the respective Approved Institution (AI)s?
# -------------------------------------------------------------------------------------------------------------------
#
# Q240:
# Can Approved Institutions (AI) deduct administrative fees from the Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q241:
# What is the deadline for me to top up the CDA?
# -------------------------------------------------------------------------------------------------------------------
#
# Q242:
# Why am I not able to use my Baby Bonus card when I still have remaining balance in the Child Development Account (CDA)?
# -------------------------------------------------------------------------------------------------------------------
#
# Q243:
# What is a Child Development Credit or CDA top-up?
# -------------------------------------------------------------------------------------------------------------------
#
# Q244:
# What are the Baby Bonus Benefits for my first or second child born in 1 January 2015 to 23 March 2016
# -------------------------------------------------------------------------------------------------------------------
#
# Q245:
# What are the Baby Bonus Benefits for my third or fourth child born in 1 January 2015 to 23 March 2016
# -------------------------------------------------------------------------------------------------------------------
#
# Q246:
# What are the Baby Bonus Benefits for my fifth or beyond child born in 1 January 2015 to 23 March 2016
# -------------------------------------------------------------------------------------------------------------------
#
# Q247:
# What are the Baby Bonus Benefits for my first or second child born in 26 August 2012 to 31 January 2014
# -------------------------------------------------------------------------------------------------------------------
#
# Q248:
# What are the Baby Bonus Benefits for my third or fourth child born in 26 August 2012 to 31 January 2014
# -------------------------------------------------------------------------------------------------------------------
#
# Q249:
# What are the Baby Bonus Benefits for my fifth or beyond child born in 26 August 2012 to 31 January 2014
# -------------------------------------------------------------------------------------------------------------------
#
# Q250:
# What are the Baby Bonus Benefits for my first or second child born in 17 August 2008 to 25 August 2012
# -------------------------------------------------------------------------------------------------------------------
#
# Q251:
# What are the Baby Bonus Benefits for my third or fourth child born in 17 August 2008 to 25 August 2012
# -------------------------------------------------------------------------------------------------------------------
#
# Q252:
# What are the Baby Bonus Benefits for my fifth or beyond child born in 17 August 2008 to 25 August 2012
# -------------------------------------------------------------------------------------------------------------------
#
# Q253:
# What are the Baby Bonus Benefits for my first child born in 1 January 2006 to 16 August 2008
# -------------------------------------------------------------------------------------------------------------------
#
# Q254:
# What are the Baby Bonus Benefits for my second child born in 1 January 2006 to 16 August 2008
# -------------------------------------------------------------------------------------------------------------------
#
# Q255:
# What are the Baby Bonus Benefits for my third and fourth child born in 1 January 2006 to 16 August 2008
# -------------------------------------------------------------------------------------------------------------------
#
# Q256:
# My spouse does not agree. I just found out that my child has joined the scheme without my agreement. Can you change the bank account holder or Child Development Account (CDA) trustee to me?
# -------------------------------------------------------------------------------------------------------------------
#
# Q257:
# My spouse is not contactable. I just found out that my child has joined the scheme without my agreement. Can you change the bank account holder or Child Development Account (CDA) trustee to me?
# -------------------------------------------------------------------------------------------------------------------
#
# Q258:
# My child is unborn, Why is my application unsuccessful?
# -------------------------------------------------------------------------------------------------------------------
#
# Q259:
# My child is a Singaporean at birth. Why is my application unsuccessful?
# -------------------------------------------------------------------------------------------------------------------
#
# Q260:
# My child was not a Singaporean at birth but has obtained Singapore Citizenship. Why is my application unsuccessful?
# -------------------------------------------------------------------------------------------------------------------
#
# Q261:
# My child is adopted at birth but has obtained Singapore Citizenship. Why is my application unsuccessful?
# -------------------------------------------------------------------------------------------------------------------
#
# Q262:
# I am the nominated CDA Trustee and I have applied for the Baby Bonus Scheme. How can I open the Child Development Account (CDA) for my child?
# -------------------------------------------------------------------------------------------------------------------
#
# Q263:
# My spouse is the nominated CDA Trustee and I have applied for the Baby Bonus Scheme. How can I open the Child Development Account (CDA) for my child?
# -------------------------------------------------------------------------------------------------------------------
#
# Q264:
# I am a foreigner and I have applied for the Baby Bonus Scheme. How can I open the Child Development Account (CDA) for my child?
# -------------------------------------------------------------------------------------------------------------------
#
# Q265:
# What is the Moments of Life (Families) app?
# -------------------------------------------------------------------------------------------------------------------
#
# Q266:
# When will new features be released on the app and how will I be notified?
# -------------------------------------------------------------------------------------------------------------------
#
# Q267:
# Who can use the app for online Birth Registration?
# -------------------------------------------------------------------------------------------------------------------
#
# Q268:
# I have registered the birth of my child on the app. What documents do I need to produce to collect my childâ€™s Birth Certificate?
# -------------------------------------------------------------------------------------------------------------------
#
# Q269:
# I registered my childâ€™s birth on the app but missed my appointment to collect my childâ€™s Birth Certificate. Can I make another appointment on the app?
# -------------------------------------------------------------------------------------------------------------------
#
# Q270:
# Why canâ€™t I make an appointment on the app to collect the Birth Certificate(s) at the hospital?
# -------------------------------------------------------------------------------------------------------------------
#
# Q271:
# If I am not the parent of the child, can I collect the childâ€™s Birth Certificate on behalf of the childâ€™s parents?
# -------------------------------------------------------------------------------------------------------------------
#
# Q272:
# Why does my spouse need to log in with SingPass as well? Can I submit the application on my spouseâ€™s behalf?
# -------------------------------------------------------------------------------------------------------------------
#
# Q273:
# My spouse does not have a SingPass account. What should I do?
# -------------------------------------------------------------------------------------------------------------------
#
# Q274:
# My spouse is overseas. Can I key in an overseas mobile number during Birth Registration?
# -------------------------------------------------------------------------------------------------------------------
#
# Q275:
# My spouse is overseas and cannot be contacted via SMS to complete the Birth Registration process. What should I do?
# -------------------------------------------------------------------------------------------------------------------
#
# Q276:
# I am a Singapore citizen, but I gave birth to my child in a private hospital. Why am I not eligible to register my baby on the app?
# -------------------------------------------------------------------------------------------------------------------
#
# Q277:
# My payment for the Birth Registration was rejected. What should I do?
# -------------------------------------------------------------------------------------------------------------------
#
# Q278:
# I did not register the birth of my child using the app. Now that I have collected my childâ€™s Birth Certificate, can I still use the app to apply for Baby Bonus?
# -------------------------------------------------------------------------------------------------------------------
#
# Q279:
# I am not married or I am separated/divorced. How can I register for the birth of my child?
# -------------------------------------------------------------------------------------------------------------------
#
# Q280:
# As a single parent, can I use the app to apply for Baby Bonus?
# -------------------------------------------------------------------------------------------------------------------
#
# Q281:
# How can I indicate interest in centres for my child who is not born yet?
# -------------------------------------------------------------------------------------------------------------------
#
# Q282:
# I want to add another centre but I have already selected 10 centres. What should I do?
# -------------------------------------------------------------------------------------------------------------------
#
# Q283:
# How can I indicate interest for kindergartens?
# -------------------------------------------------------------------------------------------------------------------
#
# Q284:
# How will I know if my child has been successful in getting a place in the centre I have indicated interest in?
# -------------------------------------------------------------------------------------------------------------------
#
# Q285:
# How do I know if a centre is a Baby Bonus Approved Institution?
# -------------------------------------------------------------------------------------------------------------------
#
# Q286:
# What are the services available under Child Health on the app?
# -------------------------------------------------------------------------------------------------------------------
#
# Q287:
# I wish to change my childâ€™s immunisation appointment, can I do so via the Moments of Life (Families) app?
# -------------------------------------------------------------------------------------------------------------------
#
# Q288:
# My childâ€™s appointment information is not updated. What should I do?
# -------------------------------------------------------------------------------------------------------------------
#
# Q289:
# What platform does the app run on?
# -------------------------------------------------------------------------------------------------------------------
#
# Q290:
# What are the services on the app that require SingPass login?
# -------------------------------------------------------------------------------------------------------------------
#
# Q291:
# I do not have SingPass account. What should I do?
# -------------------------------------------------------------------------------------------------------------------
#
# Q292:
# I have forgotten my SingPass password. What do I do?
# -------------------------------------------------------------------------------------------------------------------
#
# Q293:
# How do I indicate my interest for an infant care/child care centre?
# -------------------------------------------------------------------------------------------------------------------

# %%
from tabulate import tabulate
import pandas as pd

# CHOOSE_COUNT = First # of original questions passed for augmentation
names = ["Sense-disambiguated Synonym Substitution", "Fuzzy Question Pattern Matching", "Easy Data Augmentation Techniques"]

for i in range(CHOOSE_COUNT):
    question = questions[i]

    print(f"Q{i + 1}: \n{question}")
    print("-"*115 + "\n")
    
    nums = [len(result_symsub[question]),len(result_fpm[question]), len(result_eda[question])]
    df = pd.DataFrame({'Pipeline Name' : names,
                       '# of Questions Generated' : nums})
        print(tabulate(df, headers='keys', tablefmt='psql'))
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-754ccbd7e68a> in <module>
#       5 names = ["Sense-disambiguated Synonym Substitution", "Fuzzy Question Pattern Matching", "Easy Data Augmentation Techniques"]
#       6
# ----> 7 for i in range(CHOOSE_COUNT):
#       8     question = questions[i]
#       9
#
# NameError: name 'CHOOSE_COUNT' is not defined

# %%
def print_first_few_paraphrases_for(name: str,paraphrases: list, show_num: int = -1, is_show = True):
    if show_num == -1:
        show_num = len(paraphrases)
    if is_show:
        print(f"{name}: {show_num} out of {len(paraphrases)} paraphrases generated\n")
        for index, paraphrase in enumerate(paraphrases):
            if index is show_num:
                break
            print(f"{paraphrase}")
    else:
        # Set IS_SHOW to True to see paraphrases
        print(f"{name}: {len(paraphrases)} paraphrases generated.")
    print("-"*117 + "\n")

# Change Q_NUM, SHOW_NUM, IS_SHOW according to your preferences
Q_NUM = 8
SHOW_NUM = 10
IS_SHOW = True

question = questions[Q_NUM]
print(f"Q{Q_NUM + 1}: \n{question}")
print("-"*117 + "\n")

print_first_few_paraphrases_for("Sense-disambiguated Synonym Substitution", result_symsub[question], SHOW_NUM, IS_SHOW)

print_first_few_paraphrases_for("Fuzzy Question Pattern Matching", result_fpm[question], SHOW_NUM, IS_SHOW)

print_first_few_paraphrases_for("Easy Data Augmentation Techniques", result_eda[question], SHOW_NUM, IS_SHOW)

optimize -> optimise
# Out:
# Q9:
# How do I find out more information about Approved Institutions (AI)?
# ---------------------------------------------------------------------------------------------------------------------
#
# Sense-disambiguated Synonym Substitution: 10 out of 9 paraphrases generated
#
# How do I find out more info about Approved Institutions ( AI )?
# How do I detect out more information about Approved Institutions ( AI )?
# How do I detect out more info about Approved Institutions ( AI )?
# How do I observe out more information about Approved Institutions ( AI )?
# How do I observe out more info about Approved Institutions ( AI )?
# How do I discover out more information about Approved Institutions ( AI )?
# How do I discover out more info about Approved Institutions ( AI )?
# How do I notice out more information about Approved Institutions ( AI )?
# How do I notice out more info about Approved Institutions ( AI )?
# ---------------------------------------------------------------------------------------------------------------------
#
# Fuzzy Question Pattern Matching: 10 out of 15 paraphrases generated
#
# Where does I find out more information about Approved Institutions (AI)?
# What do I have to do to find out more information about Approved Institutions (AI)?
# Where can I find out more information about Approved Institutions (AI)?
# Where should I find out more information about Approved Institutions (AI)?
# Where shall I find out more information about Approved Institutions (AI)?
# How shall I find out more information about Approved Institutions (AI)?
# What does I need to find out more information about Approved Institutions (AI)?
# How does I find out more information about Approved Institutions (AI)?
# Where do I find out more information about Approved Institutions (AI)?
# How could I find out more information about Approved Institutions (AI)?
# ---------------------------------------------------------------------------------------------------------------------
#
# Easy Data Augmentation Techniques: 10 out of 10 paraphrases generated
#
# establishment how do i find out more information about approved institutions ai
# how do i find out more information about approved institutions ai
# how do i discover out more information about approved institutions ai
# how do i find more information approved institutions ai
# how do i witness out more information about approved institutions ai
# how do i find sanction out more information about approved institutions ai
# how do i find out more information about institutions approved ai
# how do i find out more information about approved institutions three toed sloth
# how do i find more information about approved institutions ai
# how do i find out more information about approved institutions ai
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Inspecting faqStore's babyBonus.pkl files

# %%
# name must correspond to the .pkl file name. i.e. name = babyBonus, .pkl file = babyBonus.pkl
babyBonusBani = FAQ(name = "babyBonus")
babyBonusBani.load("./faqStore")

babyBonus_name = babyBonusBani.name
babyBonus_questions = babyBonusBani.questions
babyBonus_answers = babyBonusBani.answers
babyBonus_l2Q = babyBonusBani.l2Q
babyBonus_l2A = babyBonusBani.l2A
babyBonus_FAQ_units = babyBonusBani.FAQ

# %%
print(babyBonus_FAQ_units[27].orignal.__str__())
print(babyBonus_FAQ_units[27].label)
print(dir(babyBonus_FAQ_units[0]))

# %%
import pandas as pd
df = pd.read_csv("./tutorialFAQs/babybonusTest.csv")
testData = []

for i in range(len(df)):
    orignal = df.loc[i,"original"]
    reframed = df.loc[i,"reframed"]
    
    testData.append((orignal,reframed))

# %%
visualize_question_answer(df["original"].tolist(), df["reframed"].tolist())
# Out:
# Question 1: How can my organisation apply to be a Baby Bonus Approved Institution?
#
#
# 'Apply to be a Baby Bonus Approved Institution?''
# =====================================================================================================================
# Question 2: I have entered the Unique Entity Number (UEN) using 'Join as an Approved Institution (AI)' service, but your system does not have matching records of my Unique Entity Number (UEN). Can I still submit my application?
#
#
# 'I have entered a UEN using the 'Join an AI' service, but my system does not have a matching record of my UEN. Can I still submit my application?''
# =====================================================================================================================
# Question 3: I have entered the Unique Entity Number (UEN) using the 'Join as Approved Institution (AI)' service, but your system indicated that my Unique Entity Number (UEN) is invalid, what should I do?
#
#
# 'My UEN is showing as invalid. What shoud I do?''
# =====================================================================================================================
# Question 4: Is there a validity period to be a Baby Bonus Approved Institution?
#
#
# 'Validity period to be a Baby Bonus AI?
# ''
# =====================================================================================================================
# Question 5: How much does an organisation need to pay to register as an Approved Institution (AI) with Ministry of Social and Family Development (MSF)?
#
#
# 'How much should my organisation pay to be registered as an AI withMMSF? ''
# =====================================================================================================================
